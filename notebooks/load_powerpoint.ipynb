# %% [markdown]
# # Пайплайн для загрузки и обработки PPTX -файлов

# %%
# %pip -q install unstructured
# %pip -q install python-magic
# %pip -q install python-pptx
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import UnstructuredPowerPointLoader

# %% [markdown]
# Путь до pptx файла:

# %%
import os

BASE_DIR: str = r"C:\Users\andre\IdeaProjects\DIORag"

DOCUMENTS_DIR: str = os.path.join(BASE_DIR, "documents")

FILE_PATH: str = r"C:\Users\andre\IdeaProjects\DIORag\knowledge_base\КП\1С Документооборот.pptx"

# %%
loader = UnstructuredPowerPointLoader(FILE_PATH)

documents = loader.load()

documents
# Out:
# [Document(metadata={'source': 'C:\\Users\\andre\\IdeaProjects\\DIORag\\knowledge_base\\КП\\1С Документооборот.pptx'}, page_content='«1С:Документооборот 8»\n\n\n\nКоллективное редактирование \n\nХранение документов \x0bи файлов\n\nКонтроль \x0bверсий \n\n«1С:Документооборот 8»\n\nДелопроизводство\n\nУчет рабочего \x0bвремени\n\nБизнес-процессы \n\nПолнотекстовый поиск \n\nУчет и контроль исполнения\n\n2\n\n\n\nЧто такое «1С:Документооборот 8»\n\nТиповая конфигурация для автоматизации документооборота на новой платформе «1С:Предприятие 8.3»\n\nКонфигурация ориентирована на коммерческие предприятия любой сферы деятельности\n\nПолное соответствие действующим стандартам и нормам, например:\n\nГОСТ Р 6.30-2003,\n\nГОСТ Р 51141-98,\n\nФедеральный закон Российской Федерации от 27.07.2006 г. № 149-ФЗ «Об информации, информационных технологиях и о защите информации»,\n\nТребования ГСДОУ,\n\nТиповая инструкция по делопроизводству в органах федеральной исполнительной власти,\n\nФедеральный закон от 27.07.2006 № 152-ФЗ «О персональных данных» \x0bи др.\n\nВозможность использования ЭЦП как зарегистрированного в удостоверяющем центре, так и ЭЦП для использования внутри компании для каждого сотрудника\x0b\n\n\n\nАрхитектура\n\nПрограмма ориентирована на многопользовательскую работу \x0bв локальной сети или через Интернет, в том числе и через веб-браузеры.\n\n\n\nМобильные возможности\n\nРабота с iPhone, iPad, Android\n\nСогласование через e-mail\n\nДоступ к программе из любого \x0bбраузера\n\n\n\nПреимущества «1С:Документооборот 8»\n\nЗнакомый интерфейс\n\nЛегкая интеграция с другими системами 1С в т.ч. бесшовная\n\nНе требует развертки дополнительного программного обеспечение\n\nПри наличии платформы не требует приобретения дополнительных пользовательских лицензий\n\nНе требует приобретения ежегодной подписки для работы в программе\n\n\n\nФайлы\n\n\n\nФайлы\n\nФайлы хранятся в информационной базе или в томах на диске и копируются на локальный компьютер для просмотра или редактирования по требованию пользователя.\n\nПоддерживаются любые файлы – для работы с ними используются приложения, установленные на компьютере пользователя и ассоциированные с соответствующим типом файлов.\n\nСохраняет версии файлов\n\n\n\nПапки файлов\x0bЗагрузка файлов\n\nПодходы к построению структуры папок могут быть разными, например:\n\nв соответствии с организационной структурой предприятия (например, Администрация, Бухгалтерия, Сервисная служба); \n\nпо тематике файлов (например, Планы, Калькуляции, Исследования, Рекламные материалы, Проектные документы и т.\xa0д.); \n\nпо уровню доступа (например, Общие, Конфиденциальные).\x0b\n\nЗагрузить файлы в информационную базу можно несколькими способами: \n\nперенести файлы и каталоги мышкой (Drag&Drop),\n\nимпортировать каталоги,\n\nимпортировать файлы,\n\nсоздать новый файл с выбором варианта Из файла \x0bили Со сканера.\n\n\n\nВнутренние документы\n\n\n\nВнутренние документы\n\nСправочник Внутренние документы предназначен для\xa0хранения внутренних организационно-распорядительных \x0bи информационно-справочных документов официального характера:\n\nприказы по основной \x0bдеятельности\n\nдокументы кадрового \x0bделопроизводства\n\nслужебные записки и \x0bдругие виды документов\n\nВид документа определяет:\n\nправила формирования \x0bрегистрационного \x0bномера\n\nмаршрут исполнения/ \x0bобработки документа \n\nнормативный срок \x0bисполнения документа\n\n\n\nПапки внутренних документов\n\nВсе внутренние документы хранятся в структуре папок, которая служит для упорядочивания документов и ограничения доступа к ним.\n\nСтруктуру папок удобно создавать \x0bв соответствии с организационной \x0bструктурой вашей организации \x0bили по\xa0видам документов.\n\nСостояние документа \x0bустанавливается вручную \x0bили автоматически бизнес-процессами\n\nМожно запретить изменять состояния документов вручную\n\nДополнительные свойства \x0bнастраиваются по ходу работы:\n\nОтветственным за НСИ\n\nАдминистратором\n\n\n\nВходящая и исходящ ...

# %% [markdown]
# Запись в txt файл:

# %%
FILENAME: str = "1С Документооборот.txt"

file_path = os.path.join(DOCUMENTS_DIR, FILENAME)

with open(
    file=file_path,
    mode="w",
    encoding="utf-8"
) as file:
    for document in documents:
        file.write(document.page_content + "\n")
